# %%
import pandas as pd
import pickle
import numpy as np

# %%
data = pickle.load(open("dict.pkl","rb"))

# Assuming some precedence of attributes for your data here!
index = ['Rotation', 'InitLevel', 'IsConventional', 'SoilType','Weather','ManureMass','Crop','Yield']

# %%
# Creating an empty Pandas Dataframe with the columns from above
mDf = pd.DataFrame(columns=index) 
mDf.head()
# Out:
# Empty DataFrame
# Columns: [Rotation, InitLevel, IsConventional, SoilType, Weather, ManureMass, Crop, Yield]
# Index: []

# %%
# Loading your dictionary to Pandas

df = pd.DataFrame.from_dict(data)
df
# Out:
#                      K3_170_True_JB1high_East.dwf_High  \
# Froegraes                                          NaN
# Pea                                                NaN
# Potato; Sava_Figaro                                NaN
# Rug                                                NaN
# Ryegrass                                      7.059431
# SB                                            6.546950
# SB-green                                      3.811211
# Silomajs                                     10.501223
# Spring Wheat                                       NaN
# Sugar Beet                                         NaN
# Vinterbyg                                          NaN
# Wclover                                       5.245458
# Winter Rape PA                                     NaN
# Winter Wheat JG                                    NaN
#
#                      K3_170_True_JB1high_East.dwf_Low  \
# Froegraes                                         NaN
# Pea                                               NaN
# Potato; Sava_Figaro                               NaN
# Rug                                               NaN
# Ryegrass                                     7.044489
# SB                                           6.546960
# SB-green                                     3.811211
# Silomajs                                    10.501400
# Spring Wheat                                      NaN
# Sugar Beet                                        NaN
# Vinterbyg                                         NaN
# Wclover                                      5.262339
# Winter Rape PA                                    NaN
# Winter Wheat JG                                   NaN
#
#                      K3_170_True_JB1high_East.dwf_Medium  \
# Froegraes                                            NaN
# Pea                                                  NaN
# Potato; Sava_Figaro                                  NaN
# Rug                                                  NaN
# Ryegrass                                        7.045512
# SB                                              6.546955
# SB-green                                        3.811211
# Silomajs                                       10.501140
# Spring Wheat                                         NaN
# Sugar Beet                                           NaN
# Vinterbyg                                            NaN
# Wclover                                         5.260905
# Winter Rape PA                                       NaN
# Winter Wheat JG                                      NaN
#
#                      K3_170_True_JB1high_West.dwf_High  \
# Froegraes                                          NaN
# Pea                                                NaN
# Potato; Sava_Figaro                                NaN
# Rug                                                NaN
# Ryegrass                                      6.559425
# SB                                            6.207385
# SB-green                                      3.815883
# Silomajs                                      9.382028
# Spring Wheat                                       NaN
# Sugar Beet                                         NaN
# Vinterbyg                                          NaN
# Wclover                                       5.377596
# Winter Rape PA                                     NaN
# Winter Wheat JG                                    NaN
#
#                      K3_170_True_JB1high_West.dwf_Low  \
# Froegraes                                         NaN
# Pea                                               NaN
# Potato; Sava_Figaro                               NaN
# Rug                                               NaN
# Ryegrass                                     6.553654
# SB                                           6.207395
# SB-green                                     3.815883
# Silomajs                                     9.382082
# Spring Wheat                                      NaN
# Sugar Beet                                        NaN
# Vinterbyg                                         NaN
# Wclover                                      5.406862
# Winter Rape PA                                    NaN
# Winter Wheat JG                                   NaN
#
#                      K3_170_True_JB1high_West.dwf_Medium  \
# Froegraes                                            NaN
# Pea                                                  NaN
# Potato; Sava_Figaro                                  NaN
# Rug                                                  NaN
# Ryegrass                                        6.540374
# SB                                              6.207395
# SB-green                                        3.815883
# Silomajs                                        9.382082
# Spring Wheat                                         NaN
# Sugar Beet                                           NaN
# Vinterbyg                                            NaN
# Wclover                                         5.402248
# Winter Rape PA                                       NaN
# Winter Wheat JG                                      NaN
#
#                      K3_170_True_JB1low_East.dwf_High  \
# Froegraes                                         NaN
# Pea                                               NaN
# Potato; Sava_Figaro                               NaN
# Rug                                               NaN
# Ryegrass                                     6.848856
# SB                                           6.524595
# SB-green                                     3.550750
# Silomajs                                    10.012192
# Spring Wheat                                      NaN
# Sugar Beet                                        NaN
# Vinterbyg                                         NaN
# Wclover                                      5.384676
# Winter Rape PA                                    NaN
# Winter Wheat JG                                   NaN
#
#                      K3_170_True_JB1low_East.dwf_Low  \
# Froegraes                                        NaN
# Pea                                              NaN
# Potato; Sava_Figaro                              NaN
# Rug                                              NaN
# Ryegrass                                    6.771941
# SB                                          6.524620
# SB-green                                    3.544873
# Silomajs                                    9.996331
# Spring Wheat                                     NaN
# Sugar Beet                                       NaN
# Vinterbyg                                        NaN
# Wclover                                     5.440128
# Winter Rape PA                                   NaN
# Winter Wheat JG                                  NaN
#
#                      K3_170_True_JB1low_East.dwf_Medium  \
# Froegraes                                           NaN
# Pea                                                 NaN
# Potato; Sava_Figaro                                 NaN
# Rug                                                 NaN
# Ryegrass                                       6.864145
# SB                                             6.524595
# SB-green                                       3.549423
# Silomajs                                      10.010830
# Spring Wheat                                        NaN
# Sugar Beet                                          NaN
# Vinterbyg                                           NaN
# Wclover                                        5.398483
# Winter Rape PA                                      NaN
# Winter Wheat JG                                     NaN
#
#                      K3_170_True_JB1low_West.dwf_High  \
# Froegraes                                         NaN
# Pea                                               NaN
# Potato; Sava_Figaro                               NaN
# Rug                                               NaN
# Ryegrass                                     6.454996
# SB                                           6.127575
# SB-green                                     3.328035
# Silomajs                                     9.372736
# Spring Wheat                                      NaN
# Sugar Beet                                        NaN
# Vinterbyg                                         NaN
# Wclover                                      5.505705
# Winter Rape PA                                    NaN
# Winter Wheat JG                                   NaN
#
#                                     ...                   \
# Froegraes                           ...
# Pea                                 ...
# Potato; Sava_Figaro                 ...
# Rug                                 ...
# Ryegrass                            ...
# SB                                  ...
# SB-green                            ...
# Silomajs                            ...
# Spring Wheat                        ...
# Sugar Beet                          ...
# Vinterbyg                           ...
# Wclover                             ...
# Winter Rape PA                      ...
# Winter Wheat JG                     ...
#
#                      SK1_170_True_JB6low_East.dwf_Medium  \
# Froegraes                                            NaN
# Pea                                                  NaN
# Potato; Sava_Figaro                                  NaN
# Rug                                                  NaN
# Ryegrass                                             NaN
# SB                                              5.946601
# SB-green                                             NaN
# Silomajs                                             NaN
# Spring Wheat                                         NaN
# Sugar Beet                                           NaN
# Vinterbyg                                            NaN
# Wclover                                              NaN
# Winter Rape PA                                       NaN
# Winter Wheat JG                                      NaN
#
#                      SK1_170_True_JB6low_West.dwf_High  \
# Froegraes                                          NaN
# Pea                                                NaN
# Potato; Sava_Figaro                                NaN
# Rug                                                NaN
# Ryegrass                                           NaN
# SB                                            5.860824
# SB-green                                           NaN
# Silomajs                                           NaN
# Spring Wheat                                       NaN
# Sugar Beet                                         NaN
# Vinterbyg                                          NaN
# Wclover                                            NaN
# Winter Rape PA                                     NaN
# Winter Wheat JG                                    NaN
#
#                      SK1_170_True_JB6low_West.dwf_Low  \
# Froegraes                                         NaN
# Pea                                               NaN
# Potato; Sava_Figaro                               NaN
# Rug                                               NaN
# Ryegrass                                          NaN
# SB                                           5.835098
# SB-green                                          NaN
# Silomajs                                          NaN
# Spring Wheat                                      NaN
# Sugar Beet                                        NaN
# Vinterbyg                                         NaN
# Wclover                                           NaN
# Winter Rape PA                                    NaN
# Winter Wheat JG                                   NaN
#
#                      SK1_170_True_JB6low_West.dwf_Medium  \
# Froegraes                                            NaN
# Pea                                                  NaN
# Potato; Sava_Figaro                                  NaN
# Rug                                                  NaN
# Ryegrass                                             NaN
# SB                                              5.856183
# SB-green                                             NaN
# Silomajs                                             NaN
# Spring Wheat                                         NaN
# Sugar Beet                                           NaN
# Vinterbyg                                            NaN
# Wclover                                              NaN
# Winter Rape PA                                       NaN
# Winter Wheat JG                                      NaN
#
#                      SK1_170_True_JB6med_East.dwf_High  \
# Froegraes                                          NaN
# Pea                                                NaN
# Potato; Sava_Figaro                                NaN
# Rug                                                NaN
# Ryegrass                                           NaN
# SB                                            5.957254
# SB-green                                           NaN
# Silomajs                                           NaN
# Spring Wheat                                       NaN
# Sugar Beet                                         NaN
# Vinterbyg                                          NaN
# Wclover                                            NaN
# Winter Rape PA                                     NaN
# Winter Wheat JG                                    NaN
#
#                      SK1_170_True_JB6med_East.dwf_Low  \
# Froegraes                                         NaN
# Pea                                               NaN
# Potato; Sava_Figaro                               NaN
# Rug                                               NaN
# Ryegrass                                          NaN
# SB                                           5.954269
# SB-green                                          NaN
# Silomajs                                          NaN
# Spring Wheat                                      NaN
# Sugar Beet                                        NaN
# Vinterbyg                                         NaN
# Wclover                                           NaN
# Winter Rape PA                                    NaN
# Winter Wheat JG                                   NaN
#
#                      SK1_170_True_JB6med_East.dwf_Medium  \
# Froegraes                                            NaN
# Pea                                                  NaN
# Potato; Sava_Figaro                                  NaN
# Rug                                                  NaN
# Ryegrass                                             NaN
# SB                                              5.957273
# SB-green                                             NaN
# Silomajs                                             NaN
# Spring Wheat                                         NaN
# Sugar Beet                                           NaN
# Vinterbyg                                            NaN
# Wclover                                              NaN
# Winter Rape PA                                       NaN
# Winter Wheat JG                                      NaN
#
#                      SK1_170_True_JB6med_West.dwf_High  \
# Froegraes                                          NaN
# Pea                                                NaN
# Potato; Sava_Figaro                                NaN
# Rug                                                NaN
# Ryegrass                                           NaN
# SB                                              5.9069
# SB-green                                           NaN
# Silomajs                                           NaN
# Spring Wheat                                       NaN
# Sugar Beet                                         NaN
# Vinterbyg                                          NaN
# Wclover                                            NaN
# Winter Rape PA                                     NaN
# Winter Wheat JG                                    NaN
#
#                      SK1_170_True_JB6med_West.dwf_Low  \
# Froegraes                                         NaN
# Pea                                               NaN
# Potato; Sava_Figaro                               NaN
# Rug                                               NaN
# Ryegrass                                          NaN
# SB                                           5.876999
# SB-green                                          NaN
# Silomajs                                          NaN
# Spring Wheat                                      NaN
# Sugar Beet                                        NaN
# Vinterbyg                                         NaN
# Wclover                                           NaN
# Winter Rape PA                                    NaN
# Winter Wheat JG                                   NaN
#
#                      SK1_170_True_JB6med_West.dwf_Medium
# Froegraes                                            NaN
# Pea                                                  NaN
# Potato; Sava_Figaro                                  NaN
# Rug                                                  NaN
# Ryegrass                                             NaN
# SB                                               5.89078
# SB-green                                             NaN
# Silomajs                                             NaN
# Spring Wheat                                         NaN
# Sugar Beet                                           NaN
# Vinterbyg                                            NaN
# Wclover                                              NaN
# Winter Rape PA                                       NaN
# Winter Wheat JG                                      NaN
#
# [14 rows x 1242 columns]

# %%
# Column names will be split and entered as new entries per row
colNames = list(df.columns)

# Crops are stored as row names in pandas
crops = list(df.index)

# %%
# Lot of things are going on here! 
# You can check out what's going on. 
# There are two list comprehensions: Inner one makes one row entry with your file name now appended with crop name and yield
# Outer one loops through each of the 162 entries

hierEntries = [ np.asarray([(colNames[i]+'_'+crops[b]+'_'+repr(df.iloc[b,i])).split('_') for b in range(len(crops))]) for i in range(len(df.columns))]

# The previous step results in a 3D array; changing it to 2d arrays
hierEntries = (np.asarray(hierEntries)).reshape(-1,8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b266d418cc54> in <module>()
#       7
#       8 # The previous step results in a 3D array; changing it to 2d arrays
# ----> 9 hierEntries = (np.asarray(hierEntries)).reshape(-1,8)
#
# ValueError: cannot reshape array of size 17388 into shape (8)

# %%
# Make a Pandas dataframe out of these entries
hierEntries = pd.DataFrame(hierEntries,columns=index)

# %%
# Load it into the empty frame we made
mDf = mDf.append(hierEntries)

# %%
mDf
# Out:
#      Rotation InitLevel IsConventional SoilType   Weather ManureMass  \
# 0          K3       170           True  JB1high  East.dwf       High
# 1          K3       170           True  JB1high  East.dwf       High
# 2          K3       170           True  JB1high  East.dwf       High
# 3          K3       170           True  JB1high  East.dwf       High
# 4          K3       170           True  JB1high  East.dwf       High
# 5          K3       170           True  JB1high  East.dwf       High
# 6          K3       170           True  JB1high  East.dwf       High
# 7          K3       170           True  JB1high  East.dwf        Low
# 8          K3       170           True  JB1high  East.dwf        Low
# 9          K3       170           True  JB1high  East.dwf        Low
# 10         K3       170           True  JB1high  East.dwf        Low
# 11         K3       170           True  JB1high  East.dwf        Low
# 12         K3       170           True  JB1high  East.dwf        Low
# 13         K3       170           True  JB1high  East.dwf        Low
# 14         K3       170           True  JB1high  East.dwf     Medium
# 15         K3       170           True  JB1high  East.dwf     Medium
# 16         K3       170           True  JB1high  East.dwf     Medium
# 17         K3       170           True  JB1high  East.dwf     Medium
# 18         K3       170           True  JB1high  East.dwf     Medium
# 19         K3       170           True  JB1high  East.dwf     Medium
# 20         K3       170           True  JB1high  East.dwf     Medium
# 21         K3       170           True  JB1high  West.dwf       High
# 22         K3       170           True  JB1high  West.dwf       High
# 23         K3       170           True  JB1high  West.dwf       High
# 24         K3       170           True  JB1high  West.dwf       High
# 25         K3       170           True  JB1high  West.dwf       High
# 26         K3       170           True  JB1high  West.dwf       High
# 27         K3       170           True  JB1high  West.dwf       High
# 28         K3       170           True  JB1high  West.dwf        Low
# 29         K3       170           True  JB1high  West.dwf        Low
# ...       ...       ...            ...      ...       ...        ...
# 1104      KK2       170           True   JB6med  East.dwf        Low
# 1105      KK2       170           True   JB6med  East.dwf        Low
# 1106      KK2       170           True   JB6med  East.dwf     Medium
# 1107      KK2       170           True   JB6med  East.dwf     Medium
# 1108      KK2       170           True   JB6med  East.dwf     Medium
# 1109      KK2       170           True   JB6med  East.dwf     Medium
# 1110      KK2       170           True   JB6med  East.dwf     Medium
# 1111      KK2       170           True   JB6med  East.dwf     Medium
# 1112      KK2       170           True   JB6med  East.dwf     Medium
# 1113      KK2       170           True   JB6med  West.dwf       High
# 1114      KK2       170           True   JB6med  West.dwf       High
# 1115      KK2       170           True   JB6med  West.dwf       High
# 1116      KK2       170           True   JB6med  West.dwf       High
# 1117      KK2       170           True   JB6med  West.dwf       High
# 1118      KK2       170           True   JB6med  West.dwf       High
# 1119      KK2       170           True   JB6med  West.dwf       High
# 1120      KK2       170           True   JB6med  West.dwf        Low
# 1121      KK2       170           True   JB6med  West.dwf        Low
# 1122      KK2       170           True   JB6med  West.dwf        Low
# 1123      KK2       170           True   JB6med  West.dwf        Low
# 1124      KK2       170           True   JB6med  West.dwf        Low
# 1125      KK2       170           True   JB6med  West.dwf        Low
# 1126      KK2       170           True   JB6med  West.dwf        Low
# 1127      KK2       170           True   JB6med  West.dwf     Medium
# 1128      KK2       170           True   JB6med  West.dwf     Medium
# 1129      KK2       170           True   JB6med  West.dwf     Medium
# 1130      KK2       170           True   JB6med  West.dwf     Medium
# 1131      KK2       170           True   JB6med  West.dwf     Medium
# 1132      KK2       170           True   JB6med  West.dwf     Medium
# 1133      KK2       170           True   JB6med  West.dwf     Medium
#
#                  Crop               Yield
# 0                 Rug                 nan
# 1            Ryegrass   9.285483450000001
# 2                  SB             6.54695
# 3            SB-green          3.27991525
# 4            Silomajs          10.2536995
# 5             Wclover      3.944979933125
# 6     Winter Wheat JG                 nan
# 7                 Rug                 nan
# 8            Ryegrass          9.18353605
# 9                  SB            6.546965
# 10           SB-green          3.27991525
# 11           Silomajs           10.253705
# 12            Wclover     4.0361526649375
# 13    Winter Wheat JG                 nan
# 14                Rug                 nan
# 15           Ryegrass          9.18698125
# 16                 SB            6.546965
# 17           SB-green          3.27991525
# 18           Silomajs          10.2536995
# 19            Wclover     4.0328720210625
# 20    Winter Wheat JG                 nan
# 21                Rug                 nan
# 22           Ryegrass   8.717652462499998
# 23                 SB            6.207385
# 24           SB-green          3.53864525
# 25           Silomajs           9.1252825
# 26            Wclover    4.00333748966975
# 27    Winter Wheat JG                 nan
# 28                Rug                 nan
# 29           Ryegrass        8.6268023125
# ...               ...                 ...
# 1104          Wclover  4.4742727123499995
# 1105  Winter Wheat JG                 nan
# 1106              Rug                 nan
# 1107         Ryegrass   7.365948696666666
# 1108               SB            6.560455
# 1109         SB-green   4.780924499999999
# 1110         Silomajs            9.927181
# 1111          Wclover       4.31830435725
# 1112  Winter Wheat JG                 nan
# 1113              Rug                 nan
# 1114         Ryegrass   7.188071910000001
# 1115               SB             6.21722
# 1116         SB-green   4.480482500000001
# 1117         Silomajs           9.4825745
# 1118          Wclover      4.498997150456
# 1119  Winter Wheat JG                 nan
# 1120              Rug                 nan
# 1121         Ryegrass   6.819237543333333
# 1122               SB             6.21723
# 1123         SB-green           4.4119055
# 1124         Silomajs           9.4825695
# 1125          Wclover   4.795255923333333
# 1126  Winter Wheat JG                 nan
# 1127              Rug                 nan
# 1128         Ryegrass   6.898064290000001
# 1129               SB  6.2172350000000005
# 1130         SB-green            4.444576
# 1131         Silomajs           9.4825745
# 1132          Wclover   4.635408379533334
# 1133  Winter Wheat JG                 nan
#
# [1134 rows x 8 columns]

# %%
# The coolest step is this one which just takes your frame from above and 
# makes a hierarchical array as shown below. 
# The keys to sort are all but the yield.
# This resembles the table you had printed!
hierDf = mDf.set_index(index[:-1])

# %%
hierDf
# Out:
#                                                                                              Yield
# Rotation InitLevel IsConventional SoilType Weather  ManureMass Crop
# K3       170       True           JB1high  East.dwf High       Rug                             nan
#                                                                Ryegrass          9.285483450000001
#                                                                SB                          6.54695
#                                                                SB-green                 3.27991525
#                                                                Silomajs                 10.2536995
#                                                                Wclover              3.944979933125
#                                                                Winter Wheat JG                 nan
#                                                     Low        Rug                             nan
#                                                                Ryegrass                 9.18353605
#                                                                SB                         6.546965
#                                                                SB-green                 3.27991525
#                                                                Silomajs                  10.253705
#                                                                Wclover             4.0361526649375
#                                                                Winter Wheat JG                 nan
#                                                     Medium     Rug                             nan
#                                                                Ryegrass                 9.18698125
#                                                                SB                         6.546965
#                                                                SB-green                 3.27991525
#                                                                Silomajs                 10.2536995
#                                                                Wclover             4.0328720210625
#                                                                Winter Wheat JG                 nan
#                                            West.dwf High       Rug                             nan
#                                                                Ryegrass          8.717652462499998
#                                                                SB                         6.207385
#                                                                SB-green                 3.53864525
#                                                                Silomajs                  9.1252825
#                                                                Wclover            4.00333748966975
#                                                                Winter Wheat JG                 nan
#                                                     Low        Rug                             nan
#                                                                Ryegrass               8.6268023125
# ...                                                                                            ...
# KK2      170       True           JB6med   East.dwf Low        Wclover          4.4742727123499995
#                                                                Winter Wheat JG                 nan
#                                                     Medium     Rug                             nan
#                                                                Ryegrass          7.365948696666666
#                                                                SB                         6.560455
#                                                                SB-green          4.780924499999999
#                                                                Silomajs                   9.927181
#                                                                Wclover               4.31830435725
#                                                                Winter Wheat JG                 nan
#                                            West.dwf High       Rug                             nan
#                                                                Ryegrass          7.188071910000001
#                                                                SB                          6.21722
#                                                                SB-green          4.480482500000001
#                                                                Silomajs                  9.4825745
#                                                                Wclover              4.498997150456
#                                                                Winter Wheat JG                 nan
#                                                     Low        Rug                             nan
#                                                                Ryegrass          6.819237543333333
#                                                                SB                          6.21723
#                                                                SB-green                  4.4119055
#                                                                Silomajs                  9.4825695
#                                                                Wclover           4.795255923333333
#                                                                Winter Wheat JG                 nan
#                                                     Medium     Rug                             nan
#                                                                Ryegrass          6.898064290000001
#                                                                SB               6.2172350000000005
#                                                                SB-green                   4.444576
#                                                                Silomajs                  9.4825745
#                                                                Wclover           4.635408379533334
#                                                                Winter Wheat JG                 nan
#
# [1134 rows x 1 columns]
